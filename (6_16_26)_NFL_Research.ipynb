# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlieHubbard7/NFLResearch/blob/main/(6_16_26)_NFL_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NFL Research

# %% [markdown]
# This notebook contains my work for the fifth week of work with Professor Ron Yurko at Carnegie Mellon's Sports Analytics Center. I use Madden ratings to explore what stats teams value in players of different position groups

# %% [markdown]
# ##Data Wrangling

# %% [markdown]
# ### Installs and Imports

# %%
# !pip install nflreadpy #This is from the NFLverse package: https://github.com/nflverse/nflreadpy
# !pip install rapidfuzz -q #This helps match the NFL roster with the madden data
# !pip install lifelines
# Out:
# Requirement already satisfied: nflreadpy in /usr/local/lib/python3.12/dist-packages (0.1.5)
# Requirement already satisfied: requests>=2.28.0 in /usr/local/lib/python3.12/dist-packages (from nflreadpy) (2.32.4)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from nflreadpy) (1.35.2)
# Requirement already satisfied: platformdirs>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from nflreadpy) (4.10.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from nflreadpy) (4.67.3)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from nflreadpy) (2.12.3)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from nflreadpy) (2.14.1)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->nflreadpy) (1.35.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->nflreadpy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->nflreadpy) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->nflreadpy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->nflreadpy) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0.0->nflreadpy) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->nflreadpy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->nflreadpy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->nflreadpy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28.0->nflreadpy) (2026.5.20)
# Requirement already satisfied: lifelines in /usr/local/lib/python3.12/dist-packages (0.30.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from lifelines) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from lifelines) (1.16.3)
# Requirement already satisfied: pandas<3.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from lifelines) (2.2.2)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.12/dist-packages (from lifelines) (3.10.0)
# Requirement already satisfied: autograd>=1.5 in /usr/local/lib/python3.12/dist-packages (from lifelines) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in /usr/local/lib/python3.12/dist-packages (from lifelines) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from lifelines) (1.2.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (2.22.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (4.15.0)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.12/dist-packages (from formulaic>=0.2.2->lifelines) (2.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0->lifelines) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=2.1->lifelines) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=2.1->lifelines) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->lifelines) (1.17.0)

# %%
import pandas as pd
import numpy as np
import string
import re
from scipy import stats
from scipy.stats import zscore
import math
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import nflreadpy as nfl
from rapidfuzz import fuzz, process
pd.set_option('display.max_columns', 250)
pd.set_option('display.min_rows', 10)

# %% [markdown]
# ### NFL Verse Stats

# %%
pbp = nfl.load_pbp().to_pandas() # play-by-play data
player_stats = nfl.load_player_stats().to_pandas() # player game or season statistics
team_stats = nfl.load_team_stats().to_pandas() # team game or season statistics
# schedules = nfl.load_schedules().to_pandas() # game schedules and results
players = nfl.load_players().to_pandas() # player information
rosters = nfl.load_rosters().to_pandas() # team rosters
rosters_weekly = nfl.load_rosters_weekly().to_pandas() # team rosters by season-week
snap_counts = nfl.load_snap_counts().to_pandas() # snap counts
nextgen_stats = nfl.load_nextgen_stats().to_pandas() # advanced stats from nextgenstats.nfl.com
ftn_charting = nfl.load_ftn_charting().to_pandas() # charted stats from ftnfantasy.com/data
participation = nfl.load_participation().to_pandas() # participation data (historical)
draft_picks = nfl.load_draft_picks().to_pandas() # nfl draft picks
injuries = nfl.load_injuries().to_pandas() # injury statuses and practice participation
contracts = nfl.load_contracts().to_pandas() # historical contract data from OTC
officials = nfl.load_officials().to_pandas() # officials for each game
combine = nfl.load_combine().to_pandas() # nfl combine results
depth_charts = nfl.load_depth_charts().to_pandas() # depth charts
trades = nfl.load_trades().to_pandas() # trades
ff_playerids = nfl.load_ff_playerids().to_pandas() # ffverse/dynastyprocess player ids
ff_rankings = nfl.load_ff_rankings().to_pandas() # fantasypros rankings
ff_opportunity = nfl.load_ff_opportunity().to_pandas() # expected yards, touchdowns, and fantasy points

# %% [markdown]
# ### Historical Madden Data

# %% [markdown]
# Credit to: https://github.com/theedgepredictor/nfl-madden-data/tree/main/data/madden/dataset for the data collection

# %%
madden_long = pd.read_parquet("/content/drive/MyDrive/ipynb stuff/madden_hist.parquet")
combine = nfl.load_combine().to_pandas() # nfl combine results
madden_long.head()
# Out:
#     player_id             madden_id    pfr_id        fullname high_pos_group  \
# 0  00-0004543   SHANEDRONETT_d_line  DronSh20   Shane Dronett            def
# 1  00-0012842     JASONPETER_d_line  PeteJa20     Jason Peter            def
# 2  00-0009978  LEONARDLITTLE_d_line  LittLe00  Leonard Little            def
# 3  00-0002142   JUNIORBRYANT_d_line  BryaJu20   Junior Bryant            def
# 4  00-0018054  REINARDWILSON_d_line  WilsRe20  Reinard Wilson            def
#
#   position_group position  season team  last_season_av  overallrating  \
# 0         d_line       DL    2001  ATL             1.0           75.0
# 1         d_line       DL    2001  CAR             1.0           74.0
# 2         d_line       DL    2001  LAR             1.0           73.0
# 3         d_line       DL    2001   SF             1.0           72.0
# 4         d_line       DL    2001  CIN             1.0           69.0
#
#    agility  acceleration  speed  stamina  strength  toughness  injury  \
# 0     53.0          65.0   58.0     79.0      84.0       84.0    79.0
# 1     66.0          74.0   64.0     84.0      78.0       84.0    80.0
# 2     72.0          62.0   75.0     65.0      70.0       70.0    82.0
# 3     49.0          62.0   55.0     81.0      81.0       84.0    84.0
# 4     70.0          70.0   65.0     78.0      69.0       78.0    77.0
#
#    awareness  jumping   trucking  archetype  runningstyle  changeofdirection  \
# 0       81.0     43.0   7.347195          4            11          35.306958
# 1       67.0     51.0   7.889415          5             7          47.836493
# 2       64.0     52.0  25.090824          8             9          51.656422
# 3       79.0     43.0   5.111116          5             9          36.576845
# 4       65.0     50.0  16.121217          7             9          50.852213
#
#    playrecognition  throwpower  throwaccuracyshort  throwaccuracymid  \
# 0        66.518996        11.0                20.0              20.0
# 1        58.864012        10.0                21.0              21.0
# 2        55.302556        32.0                14.0              14.0
# 3        65.727568        24.0                11.0              11.0
# 4        56.274011        31.0                16.0              16.0
#
#    throwaccuracydeep  playaction  throwonrun  carrying  ballcarriervision  \
# 0               20.0   16.696763   19.318944      28.0          -2.261149
# 1               21.0   18.295792   21.480056      24.0           0.980120
# 2               14.0   11.934877   13.800475      24.0          19.994085
# 3               11.0    9.494538   11.093699      14.0          -8.819708
# 4               16.0   16.041897   17.385281      26.0          12.748664
#
#     stiffarm   spinmove   jukemove  catching  shortrouterunning  \
# 0  -1.546120   2.340851   3.478826      22.0           6.519022
# 1  -0.375920   8.238861   7.495244      21.0           5.982346
# 2  18.021897  24.959818  21.045019      40.0           8.751804
# 3  -2.912042  -5.407254  -5.493794      14.0           7.008726
# 4   9.218156  18.243457  14.183115      26.0           7.190139
#
#    midrouterunning  deeprouterunning  spectacularcatch  catchintraffic  \
# 0        10.549796         11.996476          9.005981        8.412261
# 1         9.869347         12.073328          5.724684        4.637821
# 2        11.499611         12.645619         17.544412       14.431167
# 3        10.117281         12.240143         -1.108932       -1.319240
# 4        10.575620         11.980324         12.149089        9.289694
#
#      release  runblocking  passblocking  impactblocking  mancoverage  \
# 0   8.034401         16.0          16.0        0.483380    15.249485
# 1   9.797546         27.0          18.0        9.782409    19.028072
# 2  17.109987         16.0          24.0       -5.096101    32.979157
# 3   1.354661         29.0          27.0        7.181824    14.503342
# 4  10.978948         13.0           9.0       -2.869764    26.808503
#
#    zonecoverage  tackle   hitpower      press    pursuit  kickaccuracy  \
# 0     17.082539    81.0  51.752871   8.673651  66.456748          21.0
# 1     23.221269    72.0  54.472249  12.652961  69.286862          18.0
# 2     37.209780    74.0  51.286358  28.416331  72.007990          11.0
# 3     17.728221    82.0  51.302609   6.509206  64.948565          12.0
# 4     31.008670    69.0  51.400124  22.833778  69.883798          17.0
#
#    kickpower    return  year
# 0       24.0  0.675884  2001
# 1       19.0  3.772098  2001
# 2       33.0  1.131921  2001
# 3       14.0  1.162361  2001
# 4       21.0  2.545349  2001

# %% [markdown]
# ### Main df

# %%
contracts = nfl.load_contracts().to_pandas() # historical contract data from OTC
players = nfl.load_players().to_pandas() # player information

# %%
contracts2 = contracts.merge(players[["gsis_id", "rookie_season", "last_season"]], left_on="gsis_id", right_on="gsis_id", how="left")
contracts_short = contracts2[["player", "gsis_id", "year_signed", "apy_cap_pct", "rookie_season", "last_season"]]

# %%
position_summary_madden_long = (
    madden_long
    .groupby(["position_group", "year"])["overallrating"]
    .agg(
        mean_overall="mean",
        median_overall="median",
        n="count",
        sd="std"
    )
    .reset_index()
)

position_summary_madden_long
# Out:
#     position_group  year  mean_overall  median_overall    n         sd
# 0          d_field  2001     68.664064       69.000000  365  10.288611
# 1          d_field  2002     67.711419       66.000000  362  11.526267
# 2          d_field  2003     71.794387       70.000000  378  10.003572
# 3          d_field  2004     74.369028       72.733159  373   9.849298
# 4          d_field  2005     75.305321       74.000000  389   9.393804
# ..             ...   ...           ...             ...  ...        ...
# 219  special_teams  2021     73.408182       72.658907  146   4.759313
# 220  special_teams  2022     73.720232       73.000000  137   4.613147
# 221  special_teams  2023     74.168932       74.000000  122   4.792615
# 222  special_teams  2024     73.902958       74.000000  140   4.826510
# 223  special_teams  2025     73.079027       74.000000  136   5.915834
#
# [224 rows x 6 columns]

# %%
structure = madden_long.groupby("year")["player_id"].count().reset_index(name="n")

# %%
new_summary = (
    madden_long.groupby(['position_group', 'year'])
    .agg(
        mean_overall  = ('overallrating',  'mean'),
        median_overall= ('overallrating',  'median'),
        n             = ('player_id',      'nunique'),
        overall_sd = ("overallrating", "std"),
    )
    .reset_index()
    .round(3)
)

display(new_summary)
# Out:
#     position_group  year  mean_overall  median_overall    n  overall_sd
# 0          d_field  2001        68.664          69.000  353      10.289
# 1          d_field  2002        67.711          66.000  352      11.526
# 2          d_field  2003        71.794          70.000  344      10.004
# 3          d_field  2004        74.369          72.733  351       9.849
# 4          d_field  2005        75.305          74.000  365       9.394
# ..             ...   ...           ...             ...  ...         ...
# 219  special_teams  2021        73.408          72.659  146       4.759
# 220  special_teams  2022        73.720          73.000  137       4.613
# 221  special_teams  2023        74.169          74.000  122       4.793
# 222  special_teams  2024        73.903          74.000  140       4.827
# 223  special_teams  2025        73.079          74.000  136       5.916
#
# [224 rows x 6 columns]

# %%
madden_short = madden_long[["fullname", "player_id", "position_group", "overallrating", "year"]]
madden_short = madden_short.merge(new_summary, left_on=["position_group", "year"], right_on=["position_group", "year"], how="left")
madden_short
# Out:
#              fullname   player_id position_group  overallrating  year  \
# 0       Shane Dronett  00-0004543         d_line      75.000000  2001
# 1         Jason Peter  00-0012842         d_line      74.000000  2001
# 2      Leonard Little  00-0009978         d_line      73.000000  2001
# 3       Junior Bryant  00-0002142         d_line      72.000000  2001
# 4      Reinard Wilson  00-0018054         d_line      69.000000  2001
# ...               ...         ...            ...            ...   ...
# 62325      Jake Bates  00-0039172  special_teams      76.000000  2025
# 62326     Riley Dixon  00-0032943  special_teams      76.000000  2025
# 62327     Tory Taylor  00-0039745  special_teams      75.000000  2025
# 62328     Blake Grupe  00-0038905  special_teams      73.000000  2025
# 62329         AJ Cole  00-0035190  special_teams      79.723605  2025
#
#        mean_overall  median_overall    n  overall_sd
# 0            69.036          67.441  321      10.346
# 1            69.036          67.441  321      10.346
# 2            69.036          67.441  321      10.346
# 3            69.036          67.441  321      10.346
# 4            69.036          67.441  321      10.346
# ...             ...             ...  ...         ...
# 62325        73.079          74.000  136       5.916
# 62326        73.079          74.000  136       5.916
# 62327        73.079          74.000  136       5.916
# 62328        73.079          74.000  136       5.916
# 62329        73.079          74.000  136       5.916
#
# [62330 rows x 9 columns]

# %%
madden_short["z_overall"] = (madden_short["overallrating"] - madden_short["median_overall"]) / madden_short["overall_sd"]
madden_short.dropna(subset=["player_id"], inplace=True)
madden_short.head()
# Out:
#          fullname   player_id position_group  overallrating  year  \
# 0   Shane Dronett  00-0004543         d_line           75.0  2001
# 1     Jason Peter  00-0012842         d_line           74.0  2001
# 2  Leonard Little  00-0009978         d_line           73.0  2001
# 3   Junior Bryant  00-0002142         d_line           72.0  2001
# 4  Reinard Wilson  00-0018054         d_line           69.0  2001
#
#    mean_overall  median_overall    n  overall_sd  z_overall
# 0        69.036          67.441  321      10.346   0.730621
# 1        69.036          67.441  321      10.346   0.633965
# 2        69.036          67.441  321      10.346   0.537309
# 3        69.036          67.441  321      10.346   0.440653
# 4        69.036          67.441  321      10.346   0.150686

# %%
madden_short = madden_short.merge(players[["gsis_id", "display_name", "rookie_season", "last_season"]], left_on = "player_id", right_on = "gsis_id", how = "left")

# %%
madden_short.dropna(subset=["player_id"], inplace=True)
madden_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58616 entries, 0 to 58615
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fullname        58616 non-null  object
#  1   player_id       58616 non-null  object
#  2   position_group  58616 non-null  object
#  3   overallrating   58616 non-null  float64
#  4   year            58616 non-null  int64
#  5   mean_overall    58616 non-null  float64
#  6   median_overall  58616 non-null  float64
#  7   n               58616 non-null  int64
#  8   overall_sd      58616 non-null  float64
#  9   z_overall       58616 non-null  float64
#  10  gsis_id         58232 non-null  object
#  11  display_name    58232 non-null  object
#  12  rookie_season   58232 non-null  float64
#  13  last_season     58232 non-null  float64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 6.3+ MB

# %%
madden_short["year_number"] = madden_short["year"] - madden_short["rookie_season"] + 1
madden_short.query("year_number > 0")
# Out:
#              fullname   player_id position_group  overallrating  year  \
# 0       Shane Dronett  00-0004543         d_line      75.000000  2001
# 1         Jason Peter  00-0012842         d_line      74.000000  2001
# 2      Leonard Little  00-0009978         d_line      73.000000  2001
# 3       Junior Bryant  00-0002142         d_line      72.000000  2001
# 4      Reinard Wilson  00-0018054         d_line      69.000000  2001
# ...               ...         ...            ...            ...   ...
# 58611      Jake Bates  00-0039172  special_teams      76.000000  2025
# 58612     Riley Dixon  00-0032943  special_teams      76.000000  2025
# 58613     Tory Taylor  00-0039745  special_teams      75.000000  2025
# 58614     Blake Grupe  00-0038905  special_teams      73.000000  2025
# 58615         AJ Cole  00-0035190  special_teams      79.723605  2025
#
#        mean_overall  median_overall    n  overall_sd  z_overall     gsis_id  \
# 0            69.036          67.441  321      10.346   0.730621  00-0004543
# 1            69.036          67.441  321      10.346   0.633965  00-0012842
# 2            69.036          67.441  321      10.346   0.537309  00-0009978
# 3            69.036          67.441  321      10.346   0.440653  00-0002142
# 4            69.036          67.441  321      10.346   0.150686  00-0018054
# ...             ...             ...  ...         ...        ...         ...
# 58611        73.079          74.000  136       5.916   0.338066  00-0039172
# 58612        73.079          74.000  136       5.916   0.338066  00-0032943
# 58613        73.079          74.000  136       5.916   0.169033  00-0039745
# 58614        73.079          74.000  136       5.916  -0.169033  00-0038905
# 58615        73.079          74.000  136       5.916   0.967479  00-0035190
#
#          display_name  rookie_season  last_season  year_number
# 0       Shane Dronett         1992.0       2002.0         10.0
# 1         Jason Peter         1998.0       2001.0          4.0
# 2      Leonard Little         1998.0       2009.0          4.0
# 3       Junior Bryant         1995.0       2002.0          7.0
# 4      Reinard Wilson         1997.0       2003.0          5.0
# ...               ...            ...          ...          ...
# 58611      Jake Bates         2024.0       2026.0          2.0
# 58612     Riley Dixon         2016.0       2026.0         10.0
# 58613     Tory Taylor         2024.0       2026.0          2.0
# 58614     Blake Grupe         2023.0       2025.0          3.0
# 58615         AJ Cole         2019.0       2026.0          7.0
#
# [58165 rows x 15 columns]

# %%
madden_short = madden_short.query("year_number > 0")

# %%
summary = madden_short.groupby(["position_group", "year_number"]).agg(
    mean_z=("z_overall", "mean"),
    median_z=("z_overall", "median"),
    n=("player_id", "count")
).reset_index()

summary
# Out:
#     position_group  year_number    mean_z  median_z     n
# 0          d_field          1.0 -0.519213 -0.647668  2174
# 1          d_field          2.0 -0.216889 -0.363020  1843
# 2          d_field          3.0  0.057559 -0.123183  1554
# 3          d_field          4.0  0.299563  0.153292  1288
# 4          d_field          5.0  0.500254  0.394270  1016
# ..             ...          ...       ...       ...   ...
# 181  special_teams         22.0  1.002103  0.850495     6
# 182  special_teams         23.0  1.131052  1.062295     4
# 183  special_teams         24.0  0.879672  0.879672     1
# 184  special_teams         25.0  1.294162  1.294162     2
# 185  special_teams         26.0  0.996293  0.996293     1
#
# [186 rows x 5 columns]

# %%
groups = sorted(summary["position_group"].unique())
ncols = 3
nrows = -(-len(groups) // ncols)

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, nrows * 4), sharey=True)
axes = axes.flatten()

for i, pos in enumerate(groups):
    ax = axes[i]
    subset = summary.query("position_group == @pos").sort_values("year_number")

    ax.plot(subset["year_number"], subset["median_z"], color="steelblue", linewidth=2)

    for _, row in subset.iterrows():
        ax.annotate(
            f'n={int(row["n"])}',
            xy=(row["year_number"], row["median_z"]),
            xytext=(0, 6),
            textcoords="offset points",
            ha="center",
            fontsize=6,
            color="gray"
        )

    ax.axhline(0, linestyle="--", color="black", linewidth=0.8, alpha=0.5)
    ax.set_title(pos, fontsize=11)
    ax.set_xlabel("Year of Experience")
    ax.set_ylabel("Median Z-Overall")

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

fig.suptitle("Aging Curves by Position Group (Median Z-Overall)", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
# Get max year_number per player as their career length
career_lengths = (
    madden_short
    .groupby(["player_id", "position_group"])["year_number"]
    .max()
    .reset_index(name="career_length")
)

groups = sorted(career_lengths["position_group"].unique())
ncols = 3
nrows = -(-len(groups) // ncols)

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, nrows * 4), sharey=False)
axes = axes.flatten()

colors = [f"C{i}" for i in range(len(groups))]

for i, pos in enumerate(groups):
    ax = axes[i]
    subset = career_lengths.query("position_group == @pos")

    ax.hist(subset["career_length"], bins=range(1, int(subset["career_length"].max()) + 2),
            color=colors[i], edgecolor="white", linewidth=0.5)

    ax.set_title(pos, fontsize=11)
    ax.set_xlabel("Years of Experience")
    ax.set_ylabel("Players")

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

fig.suptitle("Distribution of Career Length by Position Group", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
from lifelines import KaplanMeierFitter

career_lengths = (
    madden_short
    .groupby(["player_id", "position_group"])["year_number"]
    .max()
    .reset_index(name="career_length")
)

groups = sorted(career_lengths["position_group"].unique())
pastel = ["#5B9BD5", "#E07B54", "#6BBF6B", "#C75B5B", "#8A6FBF", "#4FA89A", "#D4884A", "#C45B8A", "#7A7A7A"]

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(18, 12), sharey=True)
axes = axes.flatten()

for i, pos in enumerate(groups):
    ax = axes[i]
    subset = career_lengths.query("position_group == @pos")

    kmf = KaplanMeierFitter()
    kmf.fit(subset["career_length"], label=pos)
    kmf.plot_survival_function(ax=ax, color=pastel[i % len(pastel)], ci_show=True)

    ax.set_xlabel("Year of Experience")
    ax.set_ylabel("P(Still Active)")
    ax.set_title(pos, fontsize=11)
    ax.legend().remove()
    ax.axhline(0.5, linestyle="--", color="gray", linewidth=0.8, alpha=0.6)

for j in range(len(groups), len(axes)):
    axes[j].set_visible(False)

fig.suptitle("NFL Career Survival Curves by Position Group", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %%
summary
# Out:
#     position_group  year_number    mean_z  median_z     n
# 0          d_field          1.0 -0.519213 -0.647668  2174
# 1          d_field          2.0 -0.216889 -0.363020  1843
# 2          d_field          3.0  0.057559 -0.123183  1554
# 3          d_field          4.0  0.299563  0.153292  1288
# 4          d_field          5.0  0.500254  0.394270  1016
# ..             ...          ...       ...       ...   ...
# 181  special_teams         22.0  1.002103  0.850495     6
# 182  special_teams         23.0  1.131052  1.062295     4
# 183  special_teams         24.0  0.879672  0.879672     1
# 184  special_teams         25.0  1.294162  1.294162     2
# 185  special_teams         26.0  0.996293  0.996293     1
#
# [186 rows x 5 columns]

# %%
summary_ev = summary.copy()
n_max = summary_ev.groupby("position_group")["n"].transform("max")
summary_ev["p_survive"] = summary_ev["n"] / n_max
summary_ev["ev_z"] = summary_ev["median_z"] * summary_ev["p_survive"]

peak_age = (
    summary_ev
    .loc[summary_ev.groupby("position_group")["ev_z"].idxmax()]
    [["position_group", "year_number", "median_z", "ev_z", "p_survive", "n"]]
    .sort_values("year_number")
    .reset_index(drop=True)
)

display(peak_age)
# Out:
#   position_group  year_number  median_z      ev_z  p_survive    n
# 0           o_te          6.0  0.575803  0.248216   0.431078  344
# 1         o_pass          6.0  0.571686  0.179848   0.314592  470
# 2        d_field          7.0  0.849824  0.255651   0.300828  654
# 3           d_lb          7.0  0.872093  0.280562   0.321711  489
# 4         o_rush          7.0  0.835198  0.201569   0.241343  230
# 5         o_line          7.0  0.709507  0.272700   0.384352  673
# 6         d_line          8.0  0.827276  0.240409   0.290604  467
# 7    quarterback          8.0  0.348957  0.114160   0.327146  141
# 8  special_teams         14.0  0.976476  0.183935   0.188366   68

# %%
groups = sorted(summary_ev["position_group"].unique())
ncols = 3
nrows = -(-len(groups) // ncols)

colors = ["#5B9BD5", "#E07B54", "#6BBF6B", "#C75B5B", "#8A6FBF",
          "#4FA89A", "#D4884A", "#C45B8A", "#7A7A7A"]

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, nrows * 4), sharey=True)
axes = axes.flatten()

for i, pos in enumerate(groups):
    ax = axes[i]
    subset = summary_ev.query("position_group == @pos").sort_values("year_number")

    # Pull peak row directly from summary_ev instead of peak_age
    peak_row = subset.loc[subset["ev_z"].idxmax()]

    ax.plot(subset["year_number"], subset["median_z"], color="lightgray", linewidth=1.5, linestyle="--", label="Median Z")
    ax.plot(subset["year_number"], subset["ev_z"], color=colors[i], linewidth=2.5, label="EV Z")

    ax.axvline(peak_row["year_number"], color=colors[i], linewidth=1, linestyle=":", alpha=0.7)
    ax.annotate(f'Peak yr {int(peak_row["year_number"])}',
                xy=(peak_row["year_number"], peak_row["ev_z"]),
                xytext=(8, 0), textcoords="offset points",
                fontsize=8, color=colors[i])

    ax.axhline(0, linestyle="--", color="black", linewidth=0.6, alpha=0.4)
    ax.set_title(pos, fontsize=11)
    ax.set_xlabel("Year of Experience")
    ax.set_ylabel("Z-Overall")
    ax.legend(fontsize=7)

for j in range(len(groups), len(axes)):
    axes[j].set_visible(False)

fig.suptitle("Aging Curves — Median Z vs. Survival-Adjusted EV by Position Group", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# Sum of the ev of players who did play plus didn't play next year.
# -> try some different floor values for overalls of players that do not play.
#
# Look at the players change the year before they left to see where.
#
# - Can we do exepcted value for hte rest of their career?
# --> translate that back to contract value perspective.

# %%
peak_age = (
    summary_ev
    .loc[summary_ev.groupby("position_group")["ev_z"].idxmax()]
    [["position_group", "year_number", "ev_z", "n"]]
    .sort_values("year_number")
    .reset_index(drop=True)
)

colors = ["#5B9BD5", "#E07B54", "#6BBF6B", "#C75B5B", "#8A6FBF",
          "#4FA89A", "#D4884A", "#C45B8A", "#7A7A7A"]

fig, ax = plt.subplots(figsize=(12, 5))

bars = ax.bar(peak_age["position_group"], peak_age["year_number"],
              color=colors[:len(peak_age)], edgecolor="white", linewidth=0.5)

for bar, (_, row) in zip(bars, peak_age.iterrows()):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.1,
            f'Yr {int(row["year_number"])}', ha="center", va="bottom", fontsize=9, fontweight="bold")

ax.set_xlabel("Position Group")
ax.set_ylabel("Peak Year of Experience")
ax.set_title("Peak Madden Rating Year by Position Group (Survival-Adjusted EV)")
ax.tick_params(axis='x', rotation=30)
ax.set_ylim(0, peak_age["year_number"].max() + 2)
ax.axhline(peak_age["year_number"].median(), linestyle="--", color="gray", linewidth=0.8, alpha=0.6, label=f'Median peak (yr {int(peak_age["year_number"].median())})')
ax.legend(fontsize=9)
plt.tight_layout()
plt.show()

# %%
madden_drafted = madden_short.merge(
    players[["gsis_id", "draft_round"]],
    left_on="player_id", right_on="gsis_id", how="left"
)

madden_drafted["round_bucket"] = pd.cut(
    madden_drafted["draft_round"],
    bins=[0, 1, 4, 7, 8],
    labels=["Round 1", "Rounds 2-4", "Rounds 5-7", "Undrafted"],
    right=True
).fillna("Undrafted")

summary_by_round = (
    madden_drafted
    .groupby(["position_group", "round_bucket", "year_number"])
    .agg(median_z=("z_overall", "median"), n=("player_id", "count"))
    .reset_index()
)

# Survival-adjust within each position × round bucket
n_max = summary_by_round.groupby(["position_group", "round_bucket"])["n"].transform("max")
summary_by_round["p_survive"] = summary_by_round["n"] / n_max
summary_by_round["ev_z"] = summary_by_round["median_z"] * summary_by_round["p_survive"]

groups = sorted(summary_by_round["position_group"].unique())
round_colors = {"Round 1": "#5B9BD5", "Rounds 2-4": "#6BBF6B", "Rounds 5-7": "#E07B54", "Undrafted": "#C75B5B"}

ncols = 3
nrows = -(-len(groups) // ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(18, nrows * 4), sharey=True)
axes = axes.flatten()

for i, pos in enumerate(groups):
    ax = axes[i]
    subset = summary_by_round.query("position_group == @pos")

    for bucket, grp in subset.groupby("round_bucket"):
        grp = grp.sort_values("year_number")
        ax.plot(grp["year_number"], grp["ev_z"],
                color=round_colors[str(bucket)], linewidth=2, label=str(bucket))

    ax.axhline(0, linestyle="--", color="black", linewidth=0.6, alpha=0.4)
    ax.set_title(pos, fontsize=11)
    ax.set_xlabel("Year of Experience")
    ax.set_ylabel("EV Z-Overall")
    ax.legend(fontsize=7)

for j in range(len(groups), len(axes)):
    axes[j].set_visible(False)

fig.suptitle("Survival-Adjusted EV Aging Curves by Position Group × Draft Round", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_34066/2926015176.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(["position_group", "round_bucket", "year_number"])
# /tmp/ipykernel_34066/2926015176.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   n_max = summary_by_round.groupby(["position_group", "round_bucket"])["n"].transform("max")
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):
# /tmp/ipykernel_34066/2926015176.py:37: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for bucket, grp in subset.groupby("round_bucket"):

# %%
yearly_overall = madden_short.groupby("year")["overallrating"].mean().reset_index(name="mean_overall")

fig, ax = plt.subplots(figsize=(14, 5))
ax.plot(yearly_overall["year"], yearly_overall["mean_overall"], color="#5B9BD5", linewidth=2.5)
ax.scatter(yearly_overall["year"], yearly_overall["mean_overall"], color="#5B9BD5", s=40, zorder=3)

ax.set_xlabel("Year")
ax.set_ylabel("Mean Overall Rating")
ax.set_title("Average Madden Overall Rating Across All Players by Year")
ax.set_xticks(yearly_overall["year"])
ax.tick_params(axis='x', rotation=45, labelsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Stuff

# %%
madden_long.head(3)
# Out:
#     player_id             madden_id    pfr_id        fullname high_pos_group  \
# 0  00-0004543   SHANEDRONETT_d_line  DronSh20   Shane Dronett            def
# 1  00-0012842     JASONPETER_d_line  PeteJa20     Jason Peter            def
# 2  00-0009978  LEONARDLITTLE_d_line  LittLe00  Leonard Little            def
#
#   position_group position  season team  last_season_av  overallrating  \
# 0         d_line       DL    2001  ATL             1.0           75.0
# 1         d_line       DL    2001  CAR             1.0           74.0
# 2         d_line       DL    2001  LAR             1.0           73.0
#
#    agility  acceleration  speed  stamina  strength  toughness  injury  \
# 0     53.0          65.0   58.0     79.0      84.0       84.0    79.0
# 1     66.0          74.0   64.0     84.0      78.0       84.0    80.0
# 2     72.0          62.0   75.0     65.0      70.0       70.0    82.0
#
#    awareness  jumping   trucking  archetype  runningstyle  changeofdirection  \
# 0       81.0     43.0   7.347195          4            11          35.306958
# 1       67.0     51.0   7.889415          5             7          47.836493
# 2       64.0     52.0  25.090824          8             9          51.656422
#
#    playrecognition  throwpower  throwaccuracyshort  throwaccuracymid  \
# 0        66.518996        11.0                20.0              20.0
# 1        58.864012        10.0                21.0              21.0
# 2        55.302556        32.0                14.0              14.0
#
#    throwaccuracydeep  playaction  throwonrun  carrying  ballcarriervision  \
# 0               20.0   16.696763   19.318944      28.0          -2.261149
# 1               21.0   18.295792   21.480056      24.0           0.980120
# 2               14.0   11.934877   13.800475      24.0          19.994085
#
#     stiffarm   spinmove   jukemove  catching  shortrouterunning  \
# 0  -1.546120   2.340851   3.478826      22.0           6.519022
# 1  -0.375920   8.238861   7.495244      21.0           5.982346
# 2  18.021897  24.959818  21.045019      40.0           8.751804
#
#    midrouterunning  deeprouterunning  spectacularcatch  catchintraffic  \
# 0        10.549796         11.996476          9.005981        8.412261
# 1         9.869347         12.073328          5.724684        4.637821
# 2        11.499611         12.645619         17.544412       14.431167
#
#      release  runblocking  passblocking  impactblocking  mancoverage  \
# 0   8.034401         16.0          16.0        0.483380    15.249485
# 1   9.797546         27.0          18.0        9.782409    19.028072
# 2  17.109987         16.0          24.0       -5.096101    32.979157
#
#    zonecoverage  tackle   hitpower      press    pursuit  kickaccuracy  \
# 0     17.082539    81.0  51.752871   8.673651  66.456748          21.0
# 1     23.221269    72.0  54.472249  12.652961  69.286862          18.0
# 2     37.209780    74.0  51.286358  28.416331  72.007990          11.0
#
#    kickpower    return  year
# 0       24.0  0.675884  2001
# 1       19.0  3.772098  2001
# 2       33.0  1.131921  2001

# %%
madden_short.head(3)
# Out:
#          fullname   player_id position_group  overallrating  year  \
# 0   Shane Dronett  00-0004543         d_line           75.0  2001
# 1     Jason Peter  00-0012842         d_line           74.0  2001
# 2  Leonard Little  00-0009978         d_line           73.0  2001
#
#    mean_overall  median_overall    n  overall_sd  z_overall     gsis_id  \
# 0        69.036          67.441  321      10.346   0.730621  00-0004543
# 1        69.036          67.441  321      10.346   0.633965  00-0012842
# 2        69.036          67.441  321      10.346   0.537309  00-0009978
#
#      display_name  rookie_season  last_season  year_number
# 0   Shane Dronett         1992.0       2002.0         10.0
# 1     Jason Peter         1998.0       2001.0          4.0
# 2  Leonard Little         1998.0       2009.0          4.0

# %% [markdown]
# ### Looking at Contracts!

# %%
contracts.groupby("year_signed").size()
plt.figure(figsize=(13, 5))
ax = sns.barplot(contracts.groupby("year_signed").size())
ax.set_ylabel("Contracts Signed")
ax.tick_params(axis='x', labelsize=6)
ax.set_title("Contracts Signed by Year")
plt.show()

# %%
mod_contracts = contracts.query("year_signed > 2016 and year_signed < 2026")
mod_contracts.groupby("year_signed").size()
plt.figure(figsize=(13, 5))
ax = sns.barplot(mod_contracts.groupby("year_signed").size())
ax.set_ylabel("Contracts Signed")
ax.tick_params(axis='x', labelsize=6)
ax.set_title("Contracts Signed by Year")
plt.show()

# %%
contracts_cleaned = contracts.dropna(subset=['years', 'year_signed'])

def expand_contracts(df):
    rows = []
    for _, row in df.iterrows():
        for yr_offset in range(int(row['years'])):
            r = row.copy()
            r['season'] = int(row['year_signed']) + yr_offset
            rows.append(r)
    return pd.DataFrame(rows)

contracts_expanded = expand_contracts(contracts_cleaned)

# %%
contracts_expanded = (
    contracts_expanded
    .sort_values('year_signed', ascending=False)
    .drop_duplicates(subset=['player', 'season'], keep='first')
)

# %%
contracts_mod = contracts_expanded[["year_signed", "apy_cap_pct", "season", "gsis_id"]].query("season > 2016")
contracts_mod
# Out:
#        year_signed  apy_cap_pct  season     gsis_id
# 42722         2026        0.004    2026  00-0039312
# 42721         2026        0.004    2027  00-0040027
# 42721         2026        0.004    2026  00-0040027
# 42720         2026        0.004    2027  00-0039780
# 42720         2026        0.004    2026  00-0039780
# ...            ...          ...     ...         ...
# 6407          2012        0.134    2018  00-0025389
# 17424         2012        0.074    2017  00-0026166
# 50630         2012        0.030    2017  00-0027114
# 13903         2012        0.075    2017  00-0027656
# 22416         2011        0.062    2017  00-0024238
#
# [42223 rows x 4 columns]

# %%
df = madden_short.query("year > 2016").merge(contracts_mod, left_on=["player_id", "year"], right_on=["gsis_id", "season"], how="left").dropna(subset = "apy_cap_pct")
df
# Out:
#                fullname   player_id position_group  overallrating  year  \
# 0         Sharrif Floyd  00-0030574         d_line      83.000000  2017
# 1      Robert Nkemdiche  00-0032761         d_line      76.000000  2017
# 2        Jacquies Smith  00-0029112         d_line      72.000000  2017
# 3           Jordan Hill  00-0030072         d_line      72.000000  2017
# 4        Damontre Moore  00-0030069         d_line      70.000000  2017
# ...                 ...         ...            ...            ...   ...
# 25571        Jake Bates  00-0039172  special_teams      76.000000  2025
# 25572       Riley Dixon  00-0032943  special_teams      76.000000  2025
# 25573       Tory Taylor  00-0039745  special_teams      75.000000  2025
# 25574       Blake Grupe  00-0038905  special_teams      73.000000  2025
# 25575           AJ Cole  00-0035190  special_teams      79.723605  2025
#
#        mean_overall  median_overall    n  overall_sd  z_overall   gsis_id_x  \
# 0            70.598            69.0  390       8.083   1.732030  00-0030574
# 1            70.598            69.0  390       8.083   0.866015  00-0032761
# 2            70.598            69.0  390       8.083   0.371149  00-0029112
# 3            70.598            69.0  390       8.083   0.371149  00-0030072
# 4            70.598            69.0  390       8.083   0.123716  00-0030069
# ...             ...             ...  ...         ...        ...         ...
# 25571        73.079            74.0  136       5.916   0.338066  00-0039172
# 25572        73.079            74.0  136       5.916   0.338066  00-0032943
# 25573        73.079            74.0  136       5.916   0.169033  00-0039745
# 25574        73.079            74.0  136       5.916  -0.169033  00-0038905
# 25575        73.079            74.0  136       5.916   0.967479  00-0035190
#
#            display_name  rookie_season  last_season  year_number  year_signed  \
# 0         Sharrif Floyd         2013.0       2017.0          5.0       2013.0
# 1      Robert Nkemdiche         2016.0       2021.0          2.0       2016.0
# 2        Jacquies Smith         2012.0       2018.0          6.0       2017.0
# 3           Jordan Hill         2013.0       2017.0          5.0       2017.0
# 4        Damontre Moore         2013.0       2021.0          5.0       2017.0
# ...                 ...            ...          ...          ...          ...
# 25571        Jake Bates         2024.0       2026.0          2.0       2024.0
# 25572       Riley Dixon         2016.0       2026.0         10.0       2025.0
# 25573       Tory Taylor         2024.0       2026.0          2.0       2024.0
# 25574       Blake Grupe         2023.0       2025.0          3.0       2025.0
# 25575           AJ Cole         2019.0       2026.0          7.0       2025.0
#
#        apy_cap_pct  season   gsis_id_y
# 0            0.024  2017.0  00-0030574
# 1            0.014  2017.0  00-0032761
# 2            0.004  2017.0  00-0029112
# 3            0.005  2017.0  00-0030072
# 4            0.005  2017.0  00-0030069
# ...            ...     ...         ...
# 25571        0.004  2025.0  00-0039172
# 25572        0.011  2025.0  00-0032943
# 25573        0.005  2025.0  00-0039745
# 25574        0.004  2025.0  00-0038905
# 25575        0.014  2025.0  00-0035190
#
# [24316 rows x 19 columns]

# %%
df.drop(columns = ["gsis_id_x", "gsis_id_y", "season", "year_signed"])
# Out:
#                fullname   player_id position_group  overallrating  year  \
# 0         Sharrif Floyd  00-0030574         d_line      83.000000  2017
# 1      Robert Nkemdiche  00-0032761         d_line      76.000000  2017
# 2        Jacquies Smith  00-0029112         d_line      72.000000  2017
# 3           Jordan Hill  00-0030072         d_line      72.000000  2017
# 4        Damontre Moore  00-0030069         d_line      70.000000  2017
# ...                 ...         ...            ...            ...   ...
# 25571        Jake Bates  00-0039172  special_teams      76.000000  2025
# 25572       Riley Dixon  00-0032943  special_teams      76.000000  2025
# 25573       Tory Taylor  00-0039745  special_teams      75.000000  2025
# 25574       Blake Grupe  00-0038905  special_teams      73.000000  2025
# 25575           AJ Cole  00-0035190  special_teams      79.723605  2025
#
#        mean_overall  median_overall    n  overall_sd  z_overall  \
# 0            70.598            69.0  390       8.083   1.732030
# 1            70.598            69.0  390       8.083   0.866015
# 2            70.598            69.0  390       8.083   0.371149
# 3            70.598            69.0  390       8.083   0.371149
# 4            70.598            69.0  390       8.083   0.123716
# ...             ...             ...  ...         ...        ...
# 25571        73.079            74.0  136       5.916   0.338066
# 25572        73.079            74.0  136       5.916   0.338066
# 25573        73.079            74.0  136       5.916   0.169033
# 25574        73.079            74.0  136       5.916  -0.169033
# 25575        73.079            74.0  136       5.916   0.967479
#
#            display_name  rookie_season  last_season  year_number  apy_cap_pct
# 0         Sharrif Floyd         2013.0       2017.0          5.0        0.024
# 1      Robert Nkemdiche         2016.0       2021.0          2.0        0.014
# 2        Jacquies Smith         2012.0       2018.0          6.0        0.004
# 3           Jordan Hill         2013.0       2017.0          5.0        0.005
# 4        Damontre Moore         2013.0       2021.0          5.0        0.005
# ...                 ...            ...          ...          ...          ...
# 25571        Jake Bates         2024.0       2026.0          2.0        0.004
# 25572       Riley Dixon         2016.0       2026.0         10.0        0.011
# 25573       Tory Taylor         2024.0       2026.0          2.0        0.005
# 25574       Blake Grupe         2023.0       2025.0          3.0        0.004
# 25575           AJ Cole         2019.0       2026.0          7.0        0.014
#
# [24316 rows x 15 columns]

# %%
ax = sns.barplot(df.groupby("year").size())
ax.set_title("df counts by year from 2017 to 2025")
plt.show()

# %%
summary = df.query("apy_cap_pct > 0.005").groupby(["year", "position_group"])["apy_cap_pct"].mean().reset_index(name="mean_apy_cap_pct")
summary
# Out:
#     year position_group  mean_apy_cap_pct
# 0   2017        d_field          0.028039
# 1   2017           d_lb          0.029386
# 2   2017         d_line          0.031185
# 3   2017         o_line          0.030588
# 4   2017         o_pass          0.032430
# ..   ...            ...               ...
# 76  2025         o_pass          0.033817
# 77  2025         o_rush          0.019721
# 78  2025           o_te          0.023950
# 79  2025    quarterback          0.074565
# 80  2025  special_teams          0.013176
#
# [81 rows x 3 columns]

# %%
sns.lineplot(data=summary.query("position_group == 'o_rush'"), x="year", y="mean_apy_cap_pct")
plt.title("mean_apy_cap_pct by year for offensive rushers")
plt.show()

# %% [markdown]
# ### Exploring how the combine impacts madden ratings

# %%
madden_long = pd.read_parquet("/content/drive/MyDrive/ipynb stuff/madden_hist.parquet")
combine = nfl.load_combine().to_pandas() # nfl combine results

# %%
combine_df = combine.dropna(subset="forty").merge(players[["pfr_id", "gsis_id", "draft_year"]], left_on = "pfr_id", right_on = "pfr_id", how = "left")

# %%
rookie_seasons = madden_long.merge(players[["draft_year", "gsis_id"]], left_on="player_id", right_on = "gsis_id", how='left').query("year == draft_year")

# %%
rookie_seasons_and_combine = rookie_seasons.merge(combine_df[["gsis_id", "forty"]], left_on="player_id", right_on="gsis_id", how="left")

# %%
rookie_seasons_and_combine
# Out:
#        player_id                  madden_id    pfr_id         fullname  \
# 0     00-0020459       JAMALREYNOLDS_d_line  ReynJa20   Jamal Reynolds
# 1     00-0020535       JUSTINSMITH_19790920  SmitJu20     Justin Smith
# 2     00-0020426      CASEYHAMPTON_19770903  HampCa00    Casey Hampton
# 3     00-0020524        GERARDWARREN_d_line  WarrGe20    Gerard Warren
# 4     00-0020489         ANDRECARTER_d_line  CartAn20     Andre Carter
# ...          ...                        ...       ...              ...
# 5801  00-0040743       TYLERSHOUGH_19990928      None     Tyler Shough
# 5802  00-0040704     DILLONGABRIEL_20001228      None   Dillon Gabriel
# 5803  00-0040246       JULIANASHBY_20020708  AshbJu00     Julian Ashby
# 5804  00-0040074         TYLERLOOP_20010804  LoopTy00       Tyler Loop
# 5805  00-0040200  ANDRESBORREGALES_20020102  BorrAn00  Andy Borregales
#
#      high_pos_group position_group position  season team  last_season_av  \
# 0               def         d_line       DL    2001   GB        4.610860
# 1               def         d_line       DL    2001  CIN        4.610860
# 2               def         d_line       DL    2001  PIT        4.610860
# 3               def         d_line       DL    2001  CLE        4.610860
# 4               def         d_line       DL    2001   SF        4.610860
# ...             ...            ...      ...     ...  ...             ...
# 5801            off    quarterback       QB    2025   NO        4.520408
# 5802            off    quarterback       QB    2025  CLE        4.520408
# 5803             st  special_teams       LS    2025   NE        1.000000
# 5804             st  special_teams        K    2025  BAL        1.500000
# 5805             st  special_teams        K    2025   NE        1.500000
#
#       overallrating    agility  acceleration      speed    stamina   strength  \
# 0         79.000000  72.000000     83.000000  76.000000  78.000000  73.000000
# 1         79.000000  67.000000     82.000000  76.000000  85.000000  77.000000
# 2         77.000000  63.000000     66.000000  59.000000  89.000000  90.000000
# 3         76.000000  68.000000     77.000000  66.000000  85.000000  86.000000
# 4         75.000000  70.000000     72.000000  74.000000  79.000000  73.000000
# ...             ...        ...           ...        ...        ...        ...
# 5801      68.000000  77.000000     84.000000  84.000000  82.000000  56.000000
# 5802      66.000000  79.000000     86.000000  83.000000  91.000000  58.000000
# 5803      65.000000  72.000000     83.000000  74.000000  76.000000  68.000000
# 5804      73.000000  67.000000     75.000000  74.000000  83.000000  40.000000
# 5805      65.942512  68.327966     80.747823  78.430384  82.782101  49.641086
#
#       toughness     injury  awareness    jumping   trucking  archetype  \
# 0      88.00000  85.000000  64.000000  60.000000  13.928256          5
# 1      80.00000  73.000000  66.000000  58.000000   7.920525          3
# 2      82.00000  87.000000  69.000000  48.000000   9.579246          3
# 3      85.00000  90.000000  64.000000  58.000000   9.322765          3
# 4      80.00000  79.000000  66.000000  55.000000   3.157469          4
# ...         ...        ...        ...        ...        ...        ...
# 5801   82.00000  81.000000  66.000000  73.000000  40.000000          4
# 5802   90.00000  89.000000  68.000000  72.000000  34.000000          1
# 5803   86.00000  88.000000  60.000000  74.000000  45.000000          1
# 5804   66.00000  87.000000  60.000000  59.000000  12.000000          3
# 5805   67.63558  88.375453  44.032121  78.169747  17.543780          3
#
#       runningstyle  changeofdirection  playrecognition  throwpower  \
# 0               11          47.738742        52.942789   15.000000
# 1                6          40.323669        59.834627   22.000000
# 2                6          35.761971        64.084072   24.000000
# 3                7          35.344868        58.098234   15.000000
# 4                5          43.595785        57.786312   11.000000
# ...            ...                ...              ...         ...
# 5801             7          75.000000        32.000000   92.000000
# 5802             1          78.000000        29.000000   83.000000
# 5803             4          69.000000        34.000000   29.000000
# 5804             4          53.000000        14.000000   25.000000
# 5805             6          60.100093        15.068378   33.600524
#
#       throwaccuracyshort  throwaccuracymid  throwaccuracydeep  playaction  \
# 0              21.000000         21.000000           21.00000   17.356663
# 1              21.000000         21.000000           21.00000   16.433431
# 2              14.000000         14.000000           14.00000   12.866408
# 3              20.000000         20.000000           20.00000   16.730251
# 4              19.000000         19.000000           19.00000   19.153590
# ...                  ...               ...                ...         ...
# 5801           80.000000         81.000000           75.00000   83.000000
# 5802           83.000000         80.000000           80.00000   84.000000
# 5803           10.000000         11.000000           10.00000   17.000000
# 5804           30.000000         28.000000           20.00000   16.000000
# 5805           35.079801         28.984336           24.00838   18.795399
#
#       throwonrun   carrying  ballcarriervision   stiffarm   spinmove  \
# 0      20.805043  15.000000          14.519759   8.996859  23.991852
# 1      20.294446  15.000000           8.629725   2.961450  18.548155
# 2      15.389567  31.000000          -5.764664  -5.385784  -1.178711
# 3      20.169793  14.000000           6.159716   2.064359   9.003112
# 4      22.933768  14.000000           7.543041  -1.469502  25.255121
# ...          ...        ...                ...        ...        ...
# 5801   80.000000  67.000000          71.000000  38.000000  52.000000
# 5802   77.000000  62.000000          75.000000  46.000000  54.000000
# 5803   14.000000  62.000000          52.000000  47.000000  44.000000
# 5804   16.000000  34.000000          17.000000  16.000000  12.000000
# 5805   21.562364  34.432893          22.438183  15.953710  18.056983
#
#        jukemove   catching  shortrouterunning  midrouterunning  \
# 0     22.437692  33.000000          10.151774        11.892505
# 1     11.311415  19.000000          11.235782        11.530147
# 2     -7.282151  16.000000           6.692096        11.166714
# 3      5.489941  30.000000          11.909426        11.950203
# 4     20.726918  19.000000          11.903602        12.196510
# ...         ...        ...                ...              ...
# 5801  54.000000  36.000000          24.000000        23.810621
# 5802  59.000000  41.000000          21.000000        23.113776
# 5803  45.000000  45.000000          47.000000        33.833168
# 5804  18.000000  30.000000          14.000000        10.889152
# 5805  22.922098  38.311727          13.995747        12.534975
#
#       deeprouterunning  spectacularcatch  catchintraffic    release  \
# 0            12.693256         12.293937        7.395690  14.332235
# 1            11.692559          6.724469        2.138416  16.285808
# 2            13.290851          7.366448        2.750697  15.042041
# 3            11.538211          7.432284        5.451204  15.074740
# 4            11.639022          9.595415        4.653976  19.316321
# ...                ...               ...             ...        ...
# 5801         19.000000         25.000000       27.000000  27.000000
# 5802         18.000000         18.000000       21.000000  28.000000
# 5803         35.000000         47.000000       49.000000  34.000000
# 5804         10.000000         13.000000       13.000000  12.000000
# 5805         12.196400         17.873396       15.512797  13.812840
#
#       runblocking  passblocking  impactblocking  mancoverage  zonecoverage  \
# 0       11.000000     12.000000        3.324223    27.272776     29.680041
# 1       23.000000     22.000000       20.447276    25.551392     30.165120
# 2       18.000000     18.000000       -1.104908    16.861550     22.657078
# 3       15.000000     20.000000       15.245089    20.165591     25.608706
# 4       10.000000     32.000000        6.313320    33.531732     34.206993
# ...           ...           ...             ...          ...           ...
# 5801    11.000000     21.000000       23.000000    25.000000     47.000000
# 5802    18.000000     24.000000       31.000000    24.000000     48.000000
# 5803    51.000000     45.000000       56.000000    17.000000     20.000000
# 5804    10.000000     12.000000       12.000000    10.000000     11.000000
# 5805    16.652296     16.091786       15.121580    13.229934     15.440362
#
#          tackle   hitpower      press    pursuit  kickaccuracy  kickpower  \
# 0     69.000000  53.186884  22.930081  74.745695     19.000000  22.000000
# 1     72.000000  50.433495  13.792209  76.216600     20.000000  11.000000
# 2     82.000000  54.847755   7.175994  70.210879     11.000000  12.000000
# 3     79.000000  54.883390   6.512757  73.534821     18.000000  10.000000
# 4     70.000000  48.385150  19.021440  70.197263     10.000000  25.000000
# ...         ...        ...        ...        ...           ...        ...
# 5801  16.000000  15.000000  21.000000  29.000000     16.000000  30.000000
# 5802  35.000000  30.000000  22.000000  39.000000     37.000000  49.000000
# 5803  50.000000  22.000000  15.000000  52.000000     24.000000  24.000000
# 5804  20.000000  13.000000  10.000000  24.000000     72.000000  97.000000
# 5805  31.102303  22.283652  10.912919  29.596845     71.180425  93.898079
#
#          return  year  draft_year   gsis_id_x   gsis_id_y  forty
# 0      1.439833  2001      2001.0  00-0020459  00-0020459   4.72
# 1      3.217043  2001      2001.0  00-0020535  00-0020535   4.64
# 2      4.719639  2001      2001.0  00-0020426  00-0020426   5.25
# 3      3.707843  2001      2001.0  00-0020524  00-0020524   5.00
# 4      3.612164  2001      2001.0  00-0020489  00-0020489   4.84
# ...         ...   ...         ...         ...         ...    ...
# 5801  27.000000  2025      2025.0  00-0040743  00-0040743   4.63
# 5802  21.000000  2025      2025.0  00-0040704         NaN    NaN
# 5803  10.000000  2025      2025.0  00-0040246         NaN    NaN
# 5804  10.000000  2025      2025.0  00-0040074         NaN    NaN
# 5805  11.634317  2025      2025.0  00-0040200         NaN    NaN
#
# [5806 rows x 60 columns]

# %%
plt.scatter(rookie_seasons_and_combine["forty"], rookie_seasons_and_combine["speed"])
